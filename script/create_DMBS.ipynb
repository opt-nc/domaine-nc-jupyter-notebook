# %%
import pandas as pd
from graphdatascience import GraphDataScience

# %% [markdown]
# ## Setup

# %%
URI = "neo4j://localhost:7687"
password = 'password'

# %%
creds = ('neo4j', password)
gds = GraphDataScience(URI, auth=creds)

# %% [markdown]
# ## Data

# %%
df = pd.read_csv(r"C:\Users\33638\Documents\GitHub\domaine-nc-jupyter-notebook\domaine-nc.csv")

# %%
df.isProtected.value_counts()
# Out:
# False    6683
# True       19
# Name: isProtected, dtype: int64

# %%
df[df.beneficiaire.isna()]
# Out:
#                         nom extension  isProtected gestionnaire beneficiaire  \
# 949             boulouparis        nc         True          NaN          NaN
# 1364  chirurgiens-dentistes        nc         True          NaN          NaN
# 1959                  drehu        nc         True          NaN          NaN
# 2691           gouvernement        nc         True          NaN          NaN
# 2706                gratuit        nc         True          NaN          NaN
# 2931                   iaai        nc         True          NaN          NaN
# 3942         marchespublics        nc         True          NaN          NaN
# 3945                   mare        nc         True          NaN          NaN
# 4088               mercedes        nc         True          NaN          NaN
# 4256              mont-dore        nc         True          NaN          NaN
# 4259               montdore        nc         True          NaN          NaN
# 4854                  paita        nc         True          NaN          NaN
# 5455                  sages        nc         True          NaN          NaN
# 5766                    sms        nc         True          NaN          NaN
# 6216                   thio        nc         True          NaN          NaN
# 6217                thiriet        nc         True          NaN          NaN
# 6231                  tieti        nc         True          NaN          NaN
# 6619                  whois        nc         True          NaN          NaN
# 6662                   yate        nc         True          NaN          NaN
#
#      status dns1 dns2 dns3 dns4 dns5 dns6 dateCreation dateModification  \
# 949     NaN  NaN  NaN  NaN  NaN  NaN  NaN          NaN              NaN
# 1364    NaN  NaN  NaN  NaN  NaN  NaN  NaN          NaN              NaN
# 1959    NaN  NaN  NaN  NaN  NaN  NaN  NaN          NaN              NaN
# 2691    NaN  NaN  NaN  NaN  NaN  NaN  NaN          NaN              NaN
# 2706    NaN  NaN  NaN  NaN  NaN  NaN  NaN          NaN              NaN
# 2931    NaN  NaN  NaN  NaN  NaN  NaN  NaN          NaN              NaN
# 3942    NaN  NaN  NaN  NaN  NaN  NaN  NaN          NaN              NaN
# 3945    NaN  NaN  NaN  NaN  NaN  NaN  NaN          NaN              NaN
# 4088    NaN  NaN  NaN  NaN  NaN  NaN  NaN          NaN              NaN
# 4256    NaN  NaN  NaN  NaN  NaN  NaN  NaN          NaN              NaN
# 4259    NaN  NaN  NaN  NaN  NaN  NaN  NaN          NaN              NaN
# 4854    NaN  NaN  NaN  NaN  NaN  NaN  NaN          NaN              NaN
# 5455    NaN  NaN  NaN  NaN  NaN  NaN  NaN          NaN              NaN
# 5766    NaN  NaN  NaN  NaN  NaN  NaN  NaN          NaN              NaN
# 6216    NaN  NaN  NaN  NaN  NaN  NaN  NaN          NaN              NaN
# 6217    NaN  NaN  NaN  NaN  NaN  NaN  NaN          NaN              NaN
# 6231    NaN  NaN  NaN  NaN  NaN  NaN  NaN          NaN              NaN
# 6619    NaN  NaN  NaN  NaN  NaN  NaN  NaN          NaN              NaN
# 6662    NaN  NaN  NaN  NaN  NaN  NaN  NaN          NaN              NaN
#
#      dateExpiration  nbDaysBeforeExpires expired note
# 949             NaN                  NaN     NaN  NaN
# 1364            NaN                  NaN     NaN  NaN
# 1959            NaN                  NaN     NaN  NaN
# 2691            NaN                  NaN     NaN  NaN
# 2706            NaN                  NaN     NaN  NaN
# 2931            NaN                  NaN     NaN  NaN
# 3942            NaN                  NaN     NaN  NaN
# 3945            NaN                  NaN     NaN  NaN
# 4088            NaN                  NaN     NaN  NaN
# 4256            NaN                  NaN     NaN  NaN
# 4259            NaN                  NaN     NaN  NaN
# 4854            NaN                  NaN     NaN  NaN
# 5455            NaN                  NaN     NaN  NaN
# 5766            NaN                  NaN     NaN  NaN
# 6216            NaN                  NaN     NaN  NaN
# 6217            NaN                  NaN     NaN  NaN
# 6231            NaN                  NaN     NaN  NaN
# 6619            NaN                  NaN     NaN  NaN
# 6662            NaN                  NaN     NaN  NaN

# %% [markdown]
# ## CREATE CSV

# %%
gestionnaire = df.gestionnaire.unique().tolist()
gestionnaire.remove('AUCUN')
beneficiaire = df.beneficiaire.unique().tolist()
dns = df.dns1.unique().tolist() + df.dns2.unique().tolist() + df.dns3.unique().tolist() + df.dns4.unique().tolist() + df.dns5.unique().tolist() + df.dns6.unique().tolist()
dns = list(set(dns))

# %%
df_gestionnaire = pd.DataFrame({"gestionnaire":gestionnaire})
df_beneficiaire = pd.DataFrame({"beneficiaire":beneficiaire})
df_dns = pd.DataFrame({"dns":dns})

# %%
df_gestionnaire.to_csv("gestionnaires.csv",index=False)
df_beneficiaire.to_csv("beneficiaires.csv",index=False)
df_dns.to_csv("dns.csv",index=False)

# %% [markdown]
# ### Pour la suite de l'execution du Notebook, il est nécessaire de copier les 4 fichiers CSV dans le dossier import associé à la base de données neo4J

# %% [markdown]
# ![alt text](im1.png "Title")

# %% [markdown]
# ## Create Constraint

# %%
def create_constrainte(constraint):
    c = f'''
    // Create constraints
    CREATE CONSTRAINT {constraint} IF NOT EXISTS ON (i:{constraint}) ASSERT i.id IS UNIQUE;
    '''
    gds.run_cypher(c)

# %%
create_constrainte("Gestionnaires")
create_constrainte("Beneficiaires")
create_constrainte("dns")

# %% [markdown]
# ## Import Nodes

# %%
c = '''
// Load node list
LOAD CSV WITH HEADERS FROM 'file:///domaine-nc.csv' AS line
CREATE (:Site {nbDaysBeforeExpires : toInteger(line.nbDaysBeforeExpires), extension : line.extension, isProtected : line.isProtected, status : line.status, dateCreation : line.dateCreation, dateModification : line.dateModification, dateExpiration : line.dateExpiration, id: line.nom, expired : line.expired})
RETURN COUNT(*)
'''

gds.run_cypher(c)
# Out:
#    COUNT(*)
# 0      6702

# %%
c = '''
// Load node list
LOAD CSV WITH HEADERS FROM 'file:///gestionnaires.csv' AS line
WITH line
CREATE (:Gestionnaires {id:line.gestionnaire})
RETURN COUNT(*)
'''

gds.run_cypher(c)
# Out:
#    COUNT(*)
# 0        56

# %%
c = '''
// Load node list
LOAD CSV WITH HEADERS FROM 'file:///beneficiaires.csv' AS line
CREATE (:Beneficiaires {id:line.beneficiaire})
RETURN COUNT(*)
'''

gds.run_cypher(c)
# Out:
#    COUNT(*)
# 0      3596

# %%
c = '''
// Load node list
LOAD CSV WITH HEADERS FROM 'file:///dns.csv' AS line
CREATE (:dns {id:line.dns})
RETURN COUNT(*)
'''

gds.run_cypher(c)
# Out:
#    COUNT(*)
# 0      2138

# %%
c = '''
MATCH (n:Gestionnaires {id: 'AUCUN'})
DELETE n
'''
gds.run_cypher(c)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Import Edges

# %%
c = '''
// Load edge list
LOAD CSV WITH HEADERS FROM 'file:///domaine-nc.csv' AS line
WITH line
MATCH (source:Gestionnaires {id: line.gestionnaire})
MATCH (target:Site {id: line.nom})
MERGE (source)-[:GERE]->(target)
RETURN COUNT(*)
'''

gds.run_cypher(c)
# Out:
#    COUNT(*)
# 0      2471

# %%
c = '''
// Load edge list
LOAD CSV WITH HEADERS FROM 'file:///domaine-nc.csv' AS line
WITH line
MATCH (source:Beneficiaires {id: line.beneficiaire})
MATCH (target:Site {id: line.nom})
MERGE (source)-[:POSSEDE]->(target)
RETURN COUNT(*)
'''

gds.run_cypher(c)
# Out:
#    COUNT(*)
# 0      6695

# %%
c = '''
// Load edge list
LOAD CSV WITH HEADERS FROM 'file:///domaine-nc.csv' AS line
WITH line
MATCH (source:Site {id: line.nom})
MATCH (target:dns {id: line.dns1})
MERGE (source)-[:HEBERGESUR]->(target)
RETURN COUNT(*)
'''

gds.run_cypher(c)
# Out:
#    COUNT(*)
# 0      6695

# %%
c = '''
// Load edge list
LOAD CSV WITH HEADERS FROM 'file:///domaine-nc.csv' AS line
WITH line
MATCH (source:Site {id: line.nom})
MATCH (target:dns {id: line.dns2})
MERGE (source)-[:HEBERGESUR]->(target)
RETURN COUNT(*)
'''

gds.run_cypher(c)
# Out:
#    COUNT(*)
# 0      6695

# %%
c = '''
// Load edge list
LOAD CSV WITH HEADERS FROM 'file:///domaine-nc.csv' AS line
WITH line
MATCH (source:Site {id: line.nom})
MATCH (target:dns {id: line.dns3})
MERGE (source)-[:HEBERGESUR]->(target)
RETURN COUNT(*)
'''

gds.run_cypher(c)
# Out:
#    COUNT(*)
# 0      2591

# %%
c = '''
// Load edge list
LOAD CSV WITH HEADERS FROM 'file:///domaine-nc.csv' AS line
WITH line
MATCH (source:Site {id: line.nom})
MATCH (target:dns {id: line.dns4})
MERGE (source)-[:HEBERGESUR]->(target)
RETURN COUNT(*)
'''

gds.run_cypher(c)
# Out:
#    COUNT(*)
# 0      1090

# %%
c = '''
// Load edge list
LOAD CSV WITH HEADERS FROM 'file:///domaine-nc.csv' AS line
WITH line
MATCH (source:Site {id: line.nom})
MATCH (target:dns {id: line.dns5})
MERGE (source)-[:HEBERGESUR]->(target)
RETURN COUNT(*)
'''

gds.run_cypher(c)
# Out:
#    COUNT(*)
# 0       181

# %%
c = '''
// Load edge list
LOAD CSV WITH HEADERS FROM 'file:///domaine-nc.csv' AS line
WITH line
MATCH (source:Site {id: line.nom})
MATCH (target:dns {id: line.dns6})
MERGE (source)-[:HEBERGESUR]->(target)
RETURN COUNT(*)
'''

gds.run_cypher(c)
# Out:
#    COUNT(*)
# 0        37

# %%
c = '''
// Load edge list
LOAD CSV WITH HEADERS FROM 'file:///domaine-nc.csv' AS line
WITH line
MATCH (source:Beneficiaires {id: line.beneficiaire})
MATCH (target:Gestionnaires {id: line.gestionnaire})
MERGE (source)-[:CLIENTDE]->(target)
RETURN COUNT(*)
'''

gds.run_cypher(c)
# Out:
#    COUNT(*)
# 0      2466

# %% [markdown]
# ## CLEAR DMBS (Si besoin enlever les paranthèses)

# %%
"""c = '''
//
MATCH (n)
DELETE n
'''
gds.run_cypher(c)"""
# Out:
# "c = '''\n//\nMATCH (n)\nDELETE n\n'''\ngds.run_cypher(c)"
